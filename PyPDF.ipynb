# %% [markdown]
# <a href="https://colab.research.google.com/github/AlineVillarreal/Gabriela2022/blob/main/PyPDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !pip install PyPDF2
# importing required modules
import PyPDF2

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 214 kB 8.2 MB/s
# ...
# Mounted at /content/drive

# %%
# creating a pdf file object
pdfFileObj = open('/content/drive/Othercomputers/Think Pad/Documents/2019 - TextMining/PDF a Text/Papers/AppCat-2009.pdf', 'rb')

# %%
# creating a pdf reader object
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
# Out:
# WARNING:PyPDF2._reader:Xref table not zero-indexed. ID numbers for objects will be corrected.

# %%
# printing number of pages in pdf file
print(pdfReader.numPages)
# Out:
# 12

# %%
help (pdfFileObj.seek)
# Out:
# Help on built-in function seek:
#
# seek(target, whence=0, /) method of _io.BufferedReader instance
#     Change stream position.
#
#     Change the stream position to the given byte offset. The offset is
#     interpreted relative to the position indicated by whence.  Values
#     for whence are:
#
#     * 0 -- start of stream (the default); offset should be zero or positive
#     * 1 -- current stream position; offset may be negative
#     * 2 -- end of stream; offset is usually negative
#
#     Return the new absolute position.

# %%
print(pdfReader.extractText())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-45d1432e819a> in <module>()
# ----> 1 print(pdfReader.extractText())
#
# AttributeError: 'PdfFileReader' object has no attribute 'extractText'

# %%
# creating a page object
pageObj = pdfReader.getPage(0)
  
# extracting text from page
print(pageObj.extractText())
  
# closing the pdf file object
pdfFileObj.close()
# Out:
# Effect of ethyleneglycol addition on the properties of P-doped NiMo/Al 2O3HDS catalysts: Part I. Materials preparation and characterization
# Jose´Escobara,*, Marı´a C. Barreraa, Jose´A. Toledoa, Marı´a A. Corte´s-Ja´comea, Carlos Angeles-Cha´veza, Sara Nu´n˜ez
# b,V ı´ctor Santesc, Elizabeth Go´mezd, Leonardo Dı´aza, Eduardo Romeroa, Jose´G. Pachecoe
# aInstituto Mexicano del Petro ´leo, Eje Central La´zaro Ca´rdenas 152, San Bartolo Atepehuacan, Gustavo A. Madero, Me ´xico, D.F. 07730, Mexico
# bDepartamento de Ingenierı ´a de Procesos e Hidra ´ulica, Universidad Auto ´noma Metropolitana-Iztapalapa, San Rafael Atlixco 186, Me ´xico, D. F. 09340, Mexico
# cDepto. de Biociencias e Ingenierı ´a, CIIEMAD-IPN, Calle 30 de Junio de 1520, Col. Barrio la Laguna Ticoma ´n, Gustavo A. Madero, Me ´xico, D.F. 07340, Mexico
# dInstituto de Quı´mica, Universidad Nacional Auto ´noma de Me´xico, Circuito Exterior, Ciudad Universitaria, Me ´xico, D.F. 04510, Mexico
# ...

# %%
help (PyPDF2)
# Out:
# Help on package PyPDF2:
#
# NAME
#     PyPDF2
#
# DESCRIPTION
#     PyPDF2 is a free and open-source pure-python PDF library capable of splitting,
#     merging, cropping, and transforming the pages of PDF files. It can also add
#     custom data, viewing options, and passwords to PDF files. PyPDF2 can retrieve
#     text and metadata from PDFs as well.
#
#     You can read the full docs at https://pypdf2.readthedocs.io/.
#
# PACKAGE CONTENTS
#     _cmap
#     _codecs (package)
#     _encryption
#     _merger
#     _page
#     _reader
#     _security
#     _utils
#     _version
#     _writer
#     constants
#     errors
#     filters
#     generic (package)
#     pagerange
#     papersizes
#     types
#     xmp
#
# CLASSES
#     PyPDF2.generic._data_structures.DictionaryObject(builtins.dict, PyPDF2.generic._base.PdfObject)
#         PyPDF2._page.PageObject
#         PyPDF2._reader.DocumentInformation
#     builtins.object
#         PyPDF2._merger.PdfMerger
# ...
